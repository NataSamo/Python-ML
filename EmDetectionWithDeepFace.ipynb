# %% [markdown]
# <a href="https://colab.research.google.com/github/NataSamo/Python-ML/blob/main/EmDetectionWithDeepFace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 10.7 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=6d7e6de6c686d88170499d1b691354ff2e125c540b400a427e02e692bf6aa715
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 24-07-10 12:20:16 - Directory /root/.deepface created
# 24-07-10 12:20:16 - Directory /root/.deepface/weights created

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import files

# %%
files.upload()
img = cv2.imread('picture5.jpg')
# Out:
#      <input type="file" id="files-fdf0eb8b-2c48-4f3f-a277-65f91f2c19fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdf0eb8b-2c48-4f3f-a277-65f91f2c19fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.09it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.0001675638372944377,
#    'disgust': 2.1168601593846148e-08,
#    'fear': 0.024504895554855466,
#    'happy': 0.8319349959492683,
#    'sad': 0.5009330809116364,
#    'surprise': 0.0025983938030549325,
#    'neutral': 98.63986372947693},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 321,
#    'y': 230,
#    'w': 418,
#    'h': 418,
#    'left_eye': (618, 410),
#    'right_eye': (450, 375)},
#   'face_confidence': 0.91,
#   'age': 31,
#   'gender': {'Woman': 99.99927282333374, 'Man': 0.0007303557140403427},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.018567998600933867,
#    'indian': 0.011882896108077185,
#    'black': 0.0003571345843644447,
#    'white': 90.16586063315145,
#    'middle eastern': 3.728417235205503,
#    'latino hispanic': 6.0749098867285385},
#   'dominant_race': 'white'}]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 10)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions[0]['dominant_emotion'], (200,200), font, 3, (0, 0, 255), 10, cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
